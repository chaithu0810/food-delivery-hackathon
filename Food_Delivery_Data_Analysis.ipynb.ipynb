# %%
import pandas as pd
import sqlite3

# %%
orders = pd.read_csv(r"C:\Users\adlap\Downloads\orders.csv")

# %%
users = pd.read_json(r"C:\Users\adlap\Downloads\users.json")

# %%
restaurants = pd.read_sql("SELECT * FROM restaurants", conn)
restaurants.head()
# Out:
#    restaurant_id restaurant_name  cuisine  rating
# 0              1    Restaurant_1  Chinese     4.8
# 1              2    Restaurant_2   Indian     4.1
# 2              3    Restaurant_3  Mexican     4.3
# 3              4    Restaurant_4  Chinese     4.1
# 4              5    Restaurant_5  Chinese     4.8

# %%
restaurants = pd.read_sql("SELECT * FROM restaurants", conn)

# %%
restaurants.head()

# %%
final_df = (
    orders
    .merge(users, on="user_id", how="left")
    .merge(restaurants, on="restaurant_id", how="left")
)

# %%
final_df.head()

# %%
final_df.shape

# %%
final_df.columns

# %%
final_df.fillna("Unknown", inplace=True)

# %%
final_df.to_csv("final_food_delivery_dataset.csv", index=False)

# %%
import os
os.listdir()

# %%
gold_orders = final_df[final_df["membership"] == "Gold"].shape[0]
gold_orders

# %%
gold_city_revenue = (
    final_df[final_df["membership"] == "Gold"]
    .groupby("city")["total_amount"]
    .sum()
    .sort_values(ascending=False)
)
gold_city_revenue

# %%
final_df.groupby("cuisine")["total_amount"].mean().sort_values(ascending=False)

# %%
final_df[final_df["rating"] >= 4.5].shape[0]
